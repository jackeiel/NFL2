# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
df = pd.read_csv('/Users/wyssuser/Python/NFL2/DATA/master/NFL.csv', index_col=0)
print(len(df))
df.index = pd.to_datetime(df.index)
df.index.dtype
# Out:
# 5358
# dtype('<M8[ns]')

# %%
df.head()
# Out:
#             drive  sp  goal_to_go  yards_gained  shotgun  no_huddle  \
# game_date
# 2010-01-09     27  10         9.0         426.0       34          1
# 2010-01-09     26   4         4.0         340.0       46         20
# 2010-01-09     23   4         0.0         281.0       29          0
# 2010-01-09     24   7         1.0         353.0        5          0
# 2010-01-10     21  13         5.0         531.0       26          3
#
#             qb_dropback  qb_kneel  qb_spike  qb_scramble  ...  team  \
# game_date                                                 ...
# 2010-01-09         37.0         1         0            1  ...   DAL
# 2010-01-09         43.0         0         0            1  ...   PHI
# 2010-01-09         40.0         0         0            1  ...   CIN
# 2010-01-09         15.0         3         0            0  ...   NYJ
# 2010-01-10         34.0         0         0            0  ...   ARI
#
#             total_plays  home_team  away_team  win  team_score  opponent  \
# game_date
# 2010-01-09         72.0        DAL        PHI    1          34       PHI
# 2010-01-09         56.0        DAL        PHI    0          14       DAL
# 2010-01-09         61.0        CIN        NYJ    0          14       NYJ
# 2010-01-09         56.0        CIN        NYJ    1          24       CIN
# 2010-01-10         57.0        ARI         GB    0          45        GB
#
#             touchback  assist_tackle_3_team  assist_tackle_4_team
# game_date
# 2010-01-09        NaN                   NaN                   NaN
# 2010-01-09        NaN                   NaN                   NaN
# 2010-01-09        NaN                   NaN                   NaN
# 2010-01-09        NaN                   NaN                   NaN
# 2010-01-10        NaN                   NaN                   NaN
#
# [5 rows x 93 columns]

# %%
df['game_date'] = df.index
boo = df.game_date>pd.to_datetime('06/01/2014')
df = df[boo]
print(len(df))
# Out:
# 2680

# %%
df.head()
# Out:
#             drive  sp  goal_to_go  yards_gained  shotgun  no_huddle  \
# game_date
# 2019-01-05     18   2         0.0         322.0       68          0
# 2019-01-05     19   6         3.0         422.0       55          0
# 2019-01-05     24   7         3.0         380.0       34          8
# 2019-01-05     23   6         2.0         303.0       40          2
# 2019-01-06     26   5         0.0         229.0       59          6
#
#             qb_dropback  qb_kneel  qb_spike  qb_scramble  ...  total_plays  \
# game_date                                                 ...
# 2019-01-05         57.0         0         0            6  ...         68.0
# 2019-01-05         37.0         3         0            5  ...         67.0
# 2019-01-05         34.0         2         0            0  ...         68.0
# 2019-01-05         29.0         0         0            1  ...         54.0
# 2019-01-06         38.0         0         2            5  ...         59.0
#
#             home_team  away_team  win  team_score  opponent  touchback  \
# game_date
# 2019-01-05        HOU        IND    0           7       IND        3.0
# 2019-01-05        HOU        IND    1          21       HOU        2.0
# 2019-01-05        DAL        SEA    1          24       SEA        4.0
# 2019-01-05        DAL        SEA    0          22       DAL        4.0
# 2019-01-06        BAL        LAC    0          17       LAC        0.0
#
#             assist_tackle_3_team  assist_tackle_4_team  game_date
# game_date
# 2019-01-05                   0.0                   0.0 2019-01-05
# 2019-01-05                   0.0                   0.0 2019-01-05
# 2019-01-05                   0.0                   0.0 2019-01-05
# 2019-01-05                   0.0                   0.0 2019-01-05
# 2019-01-06                   0.0                   0.0 2019-01-06
#
# [5 rows x 94 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df = df.drop(['touchback', 'assist_tackle_3_team', 'assist_tackle_4_team'], axis=1)

df['third_down_perc'] = df.third_down_converted / sum(df.third_down_converted, df.third_down_failed)
df['fourth_down_perc'] = df.fourth_down_converted / sum(df.fourth_down_converted, df.fourth_down_failed)
df['pass_perc'] = df.complete_pass / sum(df.complete_pass, df.incomplete_pass)
df['spread'] = df.total_home_score - df.total_away_score
df['yards_per_deep_pass'] = df.deep_pass_yards / df.deep_pass_attempt
df['yards_per_rush'] = df.rush_yards / df.rush_attempt
df['yards_per_short_pass'] = df.short_pass_yards / df.short_pass_attempt
df['yards_per_play'] = df.yards_gained / df.total_plays

def home(row):
    if row['team'] == row['home_team']:
        return 1
    else:
        return 0
    
df['home'] = df[['team', 'home_team']].apply(home, axis=1)

# %%
score_vars = ['sp', 'total_home_score', 'total_away_score', 'touchdown', 'pass_touchdown', 'rush_touchdown',
             'extra_point_attempt', 'two_point_attempt', 'field_goal_attempt', 'field_goal_result',
             'extra_point_result', 'two_point_conv_result', 'safety', 'return_touchdown', 
              'defensive_two_point_attempt', 'defensive_two_point_conv', 'defensive_extra_point_attempt', 
              'defensive_extra_point_conv', 'win', 'spread']

# %%
df = df.drop(score_vars, axis=1)
print(len(df.columns))
# Out:
# 80

# %%
# 78 is far too many. We need to get it down to maybe 25 before we can start anything meaningful
# these represent what may be noisy variables (i.e. not associated with outcome) and variables that 
# have already been used to calculate another stat
noise = ['shotgun', 'qb_dropback', 'third_down_converted', 'third_down_failed',
         'fourth_down_converted', 'fourth_down_failed', 'punt_in_endzone',
         'punt_out_of_bounds', 'punt_downed', 'kickoff_inside_twenty',
         'kickoff_in_endzone', 'kickoff_out_of_bounds', 'kickoff_downed',
         'fumble_forced', 'fumble_not_forced', 'fumble_out_of_bounds',
         'solo_tackle', 'own_kickoff_recovery', 'own_kickoff_recovery_td',
         'kickoff_attempt', 'assist_tackle', 'lateral_reception',
         'lateral_rush', 'lateral_return', 'lateral_recovery',
         'fumble_recovery_1_yards', 'fumble_recovery_2_yards','total_plays',
         'complete_pass', 'incomplete_pass', 'deep_pass_yards',
         'deep_pass_attempt', 'rush_yards', 'rush_attempt', 'yards_gained',
         'short_pass_yards', 'short_pass_attempt', 'qb_kneel', 
        'qb_spike', 'qb_scramble', 'punt_fair_catch', 'fumble_lost',
        'deep_pass_complete', 'short_pass_complete', 'kickoff_fair_catch',
        'no_huddle', 'penalty', 'pass_length', 'penalty_yards']
df = df.drop(noise, axis=1)

# %%
for i in df.columns:
    print(i)
    
print(len(df.columns))
# Out:
# drive
# goal_to_go
# air_yards
# yards_after_catch
# punt_blocked
# first_down_rush
# first_down_pass
# first_down_penalty
# interception
# punt_inside_twenty
# tackled_for_loss
# qb_hit
# pass_attempt
# sack
# punt_attempt
# fumble
# return_yards
# team
# home_team
# away_team
# team_score
# opponent
# game_date
# third_down_perc
# fourth_down_perc
# pass_perc
# yards_per_deep_pass
# yards_per_rush
# yards_per_short_pass
# yards_per_play
# home
# 31

# %%
identifiers = ['home_team', 'away_team', 'team', 'opponent', 'team_score', 'game_date'] #also included spread as its our target

data = df.drop(identifiers, axis=1)
data = data.fillna(0)

xtrain, xtest, ytrain, ytest = train_test_split(data, df.team_score,
                                               test_size=0.30)
lm = LinearRegression()
lm.fit(xtrain, ytrain)
predictions = lm.predict(xtest)
mean_squared_error(ytest, predictions)**0.5
# Out:
# 5.259207800053701

# %%
for i in range(len(data.columns)):
    print(data.columns[i], '\t', lm.coef_[i])
# Out:
# drive 	 1.5984902474718161
# goal_to_go 	 0.14888258671167953
# air_yards 	 -0.0054375971763480375
# yards_after_catch 	 -0.004423527417383552
# punt_blocked 	 0.29985112927655433
# first_down_rush 	 0.4716440847856961
# first_down_pass 	 0.9191484579768491
# first_down_penalty 	 0.7565061733068279
# interception 	 -2.3067666448332274
# punt_inside_twenty 	 -0.03271792505876812
# tackled_for_loss 	 -0.0762435614638809
# qb_hit 	 0.032597488195953594
# pass_attempt 	 -0.4231360715886832
# sack 	 -0.07257734155786834
# punt_attempt 	 -1.4455751629266624
# fumble 	 -1.0973155777831345
# return_yards 	 0.008021744403819956
# third_down_perc 	 9257.212568903293
# fourth_down_perc 	 1745.186641763934
# pass_perc 	 3491.0849802638763
# yards_per_deep_pass 	 0.010604963555255236
# yards_per_rush 	 -0.2690125683057919
# yards_per_short_pass 	 -0.2315999254718179
# yards_per_play 	 2.761409163152245
# home 	 0.029509293540336906

# %%
[i for i in data.columns]
# Out:
# ['drive',
#  'goal_to_go',
#  'air_yards',
#  'yards_after_catch',
#  'punt_blocked',
#  'first_down_rush',
#  'first_down_pass',
#  'first_down_penalty',
#  'interception',
#  'punt_inside_twenty',
#  'tackled_for_loss',
#  'qb_hit',
#  'pass_attempt',
#  'sack',
#  'punt_attempt',
#  'fumble',
#  'return_yards',
#  'third_down_perc',
#  'fourth_down_perc',
#  'pass_perc',
#  'yards_per_deep_pass',
#  'yards_per_rush',
#  'yards_per_short_pass',
#  'yards_per_play',
#  'home']

# %%
data['team_score'] = df.team_score

# %%
data.head()
# Out:
#             drive  goal_to_go  air_yards  yards_after_catch  punt_blocked  \
# game_date
# 2019-01-05     18         0.0      352.0              139.0           0.0
# 2019-01-05     19         3.0      328.0               48.0           0.0
# 2019-01-05     24         3.0      245.0              103.0           0.0
# 2019-01-05     23         2.0      224.0               98.0           0.0
# 2019-01-06     26         0.0      250.0               95.0           0.0
#
#             first_down_rush  first_down_pass  first_down_penalty  \
# game_date
# 2019-01-05              7.0             13.0                 0.0
# 2019-01-05             10.0             14.0                 2.0
# 2019-01-05              9.0             11.0                 3.0
# 2019-01-05              5.0              6.0                 0.0
# 2019-01-06              4.0              7.0                 0.0
#
#             interception  punt_inside_twenty  ...  return_yards  \
# game_date                                     ...
# 2019-01-05           1.0                 2.0  ...          56.0
# 2019-01-05           1.0                 2.0  ...           0.0
# 2019-01-05           1.0                 1.0  ...          37.0
# 2019-01-05           0.0                 1.0  ...         132.0
# 2019-01-06           1.0                 1.0  ...         152.0
#
#             third_down_perc  fourth_down_perc  pass_perc  yards_per_deep_pass  \
# game_date
# 2019-01-05         0.000216          0.001536   0.000489             3.333333
# 2019-01-05         0.000649          0.000000   0.000320            12.125000
# 2019-01-05         0.000289          0.000000   0.000371             6.750000
# 2019-01-05         0.000144          0.001540   0.000303            23.714286
# 2019-01-06         0.000361          0.001540   0.000236            12.000000
#
#             yards_per_rush  yards_per_short_pass  yards_per_play  home  \
# game_date
# 2019-01-05        6.562500              5.000000        4.735294     1
# 2019-01-05        5.714286              5.208333        6.298507     0
# 2019-01-05        4.823529              6.862069        5.588235     1
# 2019-01-05        2.961538              3.350000        5.611111     0
# 2019-01-06        3.913043              6.090909        3.881356     1
#
#             team_score
# game_date
# 2019-01-05           7
# 2019-01-05          21
# 2019-01-05          24
# 2019-01-05          22
# 2019-01-06          17
#
# [5 rows x 26 columns]

# %%
data.pass_attempt.moving()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-563-e46637fc5cf6> in <module>
# ----> 1 data.pass_attempt.moving()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'moving'

# %%
data.rolling(5).mean().tail()
# Out:
#             drive  goal_to_go  air_yards  yards_after_catch  punt_blocked  \
# game_date
# 2016-01-03   23.0         3.6      328.4              151.2           0.0
# 2016-01-03   23.8         1.8      345.4              134.0           0.0
# 2016-01-03   24.0         2.2      346.4              124.2           0.0
# 2016-01-03   25.2         2.6      320.4              139.0           0.0
# 2016-01-03   24.4         2.6      319.8              132.6           0.0
#
#             first_down_rush  first_down_pass  first_down_penalty  \
# game_date
# 2016-01-03              7.2             12.4                 1.2
# 2016-01-03              6.0             11.8                 1.4
# 2016-01-03              5.4             12.2                 1.4
# 2016-01-03              5.6             11.6                 1.8
# 2016-01-03              5.2             11.8                 2.0
#
#             interception  punt_inside_twenty  ...  return_yards  \
# game_date                                     ...
# 2016-01-03           1.0                 1.2  ...          58.8
# 2016-01-03           1.6                 1.0  ...          86.2
# 2016-01-03           1.6                 1.0  ...          75.6
# 2016-01-03           1.4                 1.4  ...          88.0
# 2016-01-03           1.0                 1.4  ...          89.6
#
#             third_down_perc  fourth_down_perc  pass_perc  yards_per_deep_pass  \
# game_date
# 2016-01-03         0.000462          0.000154   0.000411            12.155000
# 2016-01-03         0.000447          0.000154   0.000371            11.305000
# 2016-01-03         0.000462          0.000308   0.000374            10.139286
# 2016-01-03         0.000462          0.000154   0.000371            11.834286
# 2016-01-03         0.000433          0.000154   0.000381            11.100952
#
#             yards_per_rush  yards_per_short_pass  yards_per_play  home  \
# game_date
# 2016-01-03        4.073962              7.476237        5.961930   0.4
# 2016-01-03        3.880255              7.020323        5.561930   0.6
# 2016-01-03        3.970289              6.235561        5.392713   0.4
# 2016-01-03        3.924835              6.368895        5.479749   0.6
# 2016-01-03        3.418395              5.728895        4.957408   0.4
#
#             team_score
# game_date
# 2016-01-03        23.0
# 2016-01-03        20.2
# 2016-01-03        19.8
# 2016-01-03        21.6
# 2016-01-03        19.4
#
# [5 rows x 26 columns]

# %%
data.index.sort_values()
# Out:
# DatetimeIndex(['2014-09-04', '2014-09-04', '2014-09-07', '2014-09-07',
#                '2014-09-07', '2014-09-07', '2014-09-07', '2014-09-07',
#                '2014-09-07', '2014-09-07',
#                ...
#                '2019-01-13', '2019-01-13', '2019-01-20', '2019-01-20',
#                '2019-01-20', '2019-01-20', '2019-01-27', '2019-01-27',
#                '2019-02-03', '2019-02-03'],
#               dtype='datetime64[ns]', name='game_date', length=2680, freq=None)

# %%
data.loc[data.index.sort_values(),:].rolling(5).mean()
# Out:
#             drive  goal_to_go  air_yards  yards_after_catch  punt_blocked  \
# game_date
# 2014-09-04    NaN         NaN        NaN                NaN           NaN
# 2014-09-04    NaN         NaN        NaN                NaN           NaN
# 2014-09-04    NaN         NaN        NaN                NaN           NaN
# 2014-09-04    NaN         NaN        NaN                NaN           NaN
# 2014-09-07   19.8         6.2      264.2              121.4           0.0
# 2014-09-07   20.0         5.8      280.2              142.2           0.0
# 2014-09-07   20.6         4.6      331.8              142.0           0.0
# 2014-09-07   21.6         3.8      337.4              155.6           0.0
# 2014-09-07   22.4         3.8      332.2              145.0           0.0
# 2014-09-07   22.8         3.2      335.4              142.8           0.0
# 2014-09-07   23.0         2.0      303.4              125.2           0.0
# 2014-09-07   22.4         2.4      247.2              133.6           0.2
# 2014-09-07   22.6         2.2      263.8              117.8           0.2
# 2014-09-07   23.0         1.6      275.2              130.8           0.2
# 2014-09-07   23.8         3.4      256.4              109.2           0.2
# 2014-09-07   24.8         4.2      341.8              109.4           0.4
# 2014-09-07   25.6         4.2      333.0              106.8           0.2
# 2014-09-07   25.2         3.6      295.2              105.6           0.2
# 2014-09-07   26.2         3.0      307.4              100.8           0.2
# 2014-09-07   26.6         1.4      350.8              110.4           0.2
# 2014-09-07   26.2         1.2      295.6              100.8           0.0
# 2014-09-07   26.4         1.8      331.2              103.4           0.0
# 2014-09-07   26.4         2.2      321.6              108.4           0.0
# 2014-09-07   24.6         2.2      320.0              105.8           0.0
# 2014-09-07   22.4         2.6      295.6              105.8           0.0
# 2014-09-07   21.4         2.4      267.6              110.2           0.0
# 2014-09-07   20.6         1.8      245.2               95.6           0.0
# 2014-09-07   20.4         2.0      269.0               84.4           0.0
# 2014-09-07   20.8         4.0      266.2               91.6           0.0
# 2014-09-07   21.8         5.8      272.2              108.8           0.0
# ...           ...         ...        ...                ...           ...
# 2019-01-13   21.2         5.2      363.0              139.4           0.0
# 2019-01-13   21.0         4.4      351.2              130.2           0.0
# 2019-01-13   21.8         4.8      404.0              138.2           0.0
# 2019-01-13   22.0         5.6      324.8              156.2           0.0
# 2019-01-13   21.2         5.2      363.0              139.4           0.0
# 2019-01-13   21.0         4.4      351.2              130.2           0.0
# 2019-01-20   21.8         5.8      343.8              139.0           0.0
# 2019-01-20   21.6         5.8      276.4              140.8           0.0
# 2019-01-20   21.0         4.6      324.2              123.8           0.0
# 2019-01-20   21.6         5.0      327.4              127.4           0.0
# 2019-01-20   22.4         6.4      320.0              136.2           0.0
# 2019-01-20   22.2         5.4      312.8              137.2           0.0
# 2019-01-20   22.0         5.0      348.8              136.4           0.0
# 2019-01-20   22.4         6.2      342.4              140.2           0.0
# 2019-01-20   22.4         6.4      320.0              136.2           0.0
# 2019-01-20   22.2         5.4      312.8              137.2           0.0
# 2019-01-20   22.0         5.0      348.8              136.4           0.0
# 2019-01-20   22.4         6.2      342.4              140.2           0.0
# 2019-01-20   22.4         6.4      320.0              136.2           0.0
# 2019-01-20   22.2         5.4      312.8              137.2           0.0
# 2019-01-20   22.0         5.0      348.8              136.4           0.0
# 2019-01-20   22.4         6.2      342.4              140.2           0.0
# 2019-01-27   21.8         6.2      370.4              146.8           0.0
# 2019-01-27   21.4         4.4      372.0              131.8           0.0
# 2019-01-27   21.0         5.2      429.6              141.4           0.0
# 2019-01-27   21.0         4.8      402.4              126.2           0.0
# 2019-02-03   21.2         3.2      403.4              111.0           0.0
# 2019-02-03   22.2         1.8      351.4               99.4           0.0
# 2019-02-03   22.8         1.8      373.2              103.2           0.0
# 2019-02-03   23.8         0.4      321.2               91.6           0.0
#
#             first_down_rush  first_down_pass  first_down_penalty  \
# game_date
# 2014-09-04              NaN              NaN                 NaN
# 2014-09-04              NaN              NaN                 NaN
# 2014-09-04              NaN              NaN                 NaN
# 2014-09-04              NaN              NaN                 NaN
# 2014-09-07              8.0             12.6                 2.6
# 2014-09-07              9.0             13.4                 3.0
# 2014-09-07              8.0             15.0                 2.6
# 2014-09-07              8.0             14.6                 2.4
# 2014-09-07              6.8             14.6                 1.6
# 2014-09-07              6.6             14.2                 2.4
# 2014-09-07              5.8             12.4                 2.2
# 2014-09-07              5.6             11.4                 2.2
# 2014-09-07              5.0             11.4                 2.6
# 2014-09-07              4.6             13.4                 2.8
# 2014-09-07              5.8             11.6                 2.6
# 2014-09-07              6.2             12.4                 2.2
# 2014-09-07              6.8             12.0                 2.0
# 2014-09-07              7.0             11.2                 1.8
# 2014-09-07              6.4             10.4                 2.0
# 2014-09-07              5.6             11.2                 1.8
# 2014-09-07              6.0             11.0                 2.2
# 2014-09-07              5.2             12.4                 2.4
# 2014-09-07              6.0             13.0                 2.4
# 2014-09-07              6.4             12.2                 2.2
# 2014-09-07              6.6             12.2                 2.4
# 2014-09-07              6.0             12.2                 2.2
# 2014-09-07              5.8             11.8                 1.8
# 2014-09-07              5.6             11.8                 1.8
# 2014-09-07              6.4             12.4                 2.2
# 2014-09-07              5.2             13.6                 1.8
# ...                     ...              ...                 ...
# 2019-01-13              6.4             14.6                 2.4
# 2019-01-13              5.0             14.0                 2.4
# 2019-01-13              5.0             15.0                 2.8
# 2019-01-13              6.6             15.4                 2.4
# 2019-01-13              6.4             14.6                 2.4
# 2019-01-13              5.0             14.0                 2.4
# 2019-01-20              5.6             14.6                 2.0
# 2019-01-20              6.2             13.8                 1.6
# 2019-01-20              4.8             12.4                 2.0
# 2019-01-20              6.0             13.6                 1.8
# 2019-01-20              6.6             14.2                 1.4
# 2019-01-20              6.6             13.8                 1.8
# 2019-01-20              6.2             13.6                 2.2
# 2019-01-20              8.6             15.4                 1.6
# 2019-01-20              6.6             14.2                 1.4
# 2019-01-20              6.6             13.8                 1.8
# 2019-01-20              6.2             13.6                 2.2
# 2019-01-20              8.6             15.4                 1.6
# 2019-01-20              6.6             14.2                 1.4
# 2019-01-20              6.6             13.8                 1.8
# 2019-01-20              6.2             13.6                 2.2
# 2019-01-20              8.6             15.4                 1.6
# 2019-01-27              6.8             14.8                 1.6
# 2019-01-27              6.2             13.2                 2.0
# 2019-01-27              6.4             14.2                 1.8
# 2019-01-27              6.2             13.2                 1.4
# 2019-02-03              3.6             11.4                 1.4
# 2019-02-03              3.6             10.4                 2.0
# 2019-02-03              3.6             11.4                 1.8
# 2019-02-03              3.6             10.4                 2.4
#
#             interception  punt_inside_twenty  ...  return_yards  \
# game_date                                     ...
# 2014-09-04           NaN                 NaN  ...           NaN
# 2014-09-04           NaN                 NaN  ...           NaN
# 2014-09-04           NaN                 NaN  ...           NaN
# 2014-09-04           NaN                 NaN  ...           NaN
# 2014-09-07           0.4                 1.2  ...          73.4
# 2014-09-07           0.4                 1.4  ...          57.8
# 2014-09-07           0.6                 1.4  ...          76.8
# 2014-09-07           0.4                 1.8  ...          54.6
# 2014-09-07           0.6                 2.2  ...          51.4
# 2014-09-07           1.0                 2.4  ...          63.6
# 2014-09-07           0.8                 2.4  ...          69.4
# 2014-09-07           0.6                 2.4  ...          55.2
# 2014-09-07           1.2                 2.2  ...          68.2
# 2014-09-07           1.0                 2.0  ...          73.2
# 2014-09-07           0.8                 1.8  ...          74.8
# 2014-09-07           0.8                 1.8  ...          82.2
# 2014-09-07           1.0                 1.8  ...          80.2
# 2014-09-07           0.4                 1.4  ...          83.2
# 2014-09-07           0.4                 1.2  ...          89.0
# 2014-09-07           0.4                 2.2  ...          81.4
# 2014-09-07           0.4                 2.0  ...          87.4
# 2014-09-07           0.4                 2.0  ...          78.4
# 2014-09-07           0.4                 2.2  ...          76.4
# 2014-09-07           0.8                 2.2  ...          79.4
# 2014-09-07           1.2                 1.2  ...          92.8
# 2014-09-07           1.2                 1.6  ...          66.6
# 2014-09-07           1.0                 1.6  ...          72.0
# 2014-09-07           1.4                 1.8  ...          76.0
# 2014-09-07           1.0                 1.6  ...          58.2
# 2014-09-07           0.8                 1.6  ...          38.6
# ...                  ...                 ...  ...           ...
# 2019-01-13           1.0                 1.0  ...          63.0
# 2019-01-13           1.2                 1.6  ...          62.2
# 2019-01-13           1.0                 1.2  ...          86.2
# 2019-01-13           0.8                 1.2  ...          58.6
# 2019-01-13           1.0                 1.0  ...          63.0
# 2019-01-13           1.2                 1.6  ...          62.2
# 2019-01-20           1.0                 1.2  ...          57.6
# 2019-01-20           1.0                 1.4  ...          49.2
# 2019-01-20           1.0                 1.4  ...          75.4
# 2014-09-07        3.888642              5.285776        4.536942   0.4
# 2014-09-07        4.218642              5.192186        4.965067   0.4
# 2014-09-07        3.878726              5.592186        5.209572   0.4
# 2014-09-07        4.785393              6.144567        5.800388   0.4
# 2014-09-07        4.927938              6.342165        5.947940   0.6
# 2014-09-07        5.126036              6.527111        6.136248   0.6
# 2014-09-07        4.732703              7.098164        6.090993   0.6
# 2014-09-07        4.510408              6.148830        5.610660   0.4
# 2014-09-07        4.470408              5.790228        5.334946   0.6
# 2014-09-07        4.453363              6.023945        5.371799   0.6
# 2014-09-07        4.120444              6.348389        5.324814   0.4
# ...                    ...                   ...             ...   ...
# 2019-01-13        3.672007              6.058514        5.743873   0.6
# 2019-01-13        3.400636              5.872007        5.624604   0.4
# 2019-01-13        3.168136              5.591638        5.597698   0.4
# 2019-01-13        3.699900              6.011790        5.837698   0.6
# 2019-01-13        3.672007              6.058514        5.743873   0.6
# 2019-01-13        3.400636              5.872007        5.624604   0.4
# 2019-01-20        3.380443              5.758219        5.672539   0.4
# 2019-01-20        3.457586              6.017815        5.541866   0.6
# 2019-01-20        3.229155              6.302288        5.498986   0.6
# 2019-01-20        3.078617              6.431645        5.430781   0.4
# 2019-01-20        3.058425              6.317856        5.478716   0.4
# 2019-01-20        2.923260              6.410872        5.273201   0.6
# 2019-01-20        3.149451              6.855901        5.600993   0.6
# 2019-01-20        3.199451              6.747509        5.481844   0.4
# 2019-01-20        3.058425              6.317856        5.478716   0.4
# 2019-01-20        2.923260              6.410872        5.273201   0.6
# 2019-01-20        3.149451              6.855901        5.600993   0.6
# 2019-01-20        3.199451              6.747509        5.481844   0.4
# 2019-01-20        3.058425              6.317856        5.478716   0.4
# 2019-01-20        2.923260              6.410872        5.273201   0.6
# 2019-01-20        3.149451              6.855901        5.600993   0.6
# 2019-01-20        3.199451              6.747509        5.481844   0.4
# 2019-01-27        3.066117              6.730944        5.627557   0.4
# 2019-01-27        3.518254              6.506788        5.173570   0.6
# 2019-01-27        3.661111              6.826860        5.527926   0.4
# 2019-01-27        4.022222              6.064659        4.951661   0.4
# 2019-02-03        3.977778              5.652808        4.703434   0.6
# 2019-02-03        4.340278              5.622775        4.639887   0.6
# 2019-02-03        3.984722              5.864733        4.848776   0.6
# 2019-02-03        4.347222              5.834700        4.785229   0.6
#
#             team_score
# game_date
# 2014-09-04         NaN
# 2014-09-04         NaN
# 2014-09-04         NaN
# 2014-09-04         NaN
# 2014-09-07        28.2
# 2014-09-07        31.8
# 2014-09-07        27.8
# 2014-09-07        29.2
# 2014-09-07        26.6
# 2014-09-07        23.2
# 2014-09-07        19.6
# 2014-09-07        17.6
# 2014-09-07        15.0
# 2014-09-07        15.6
# 2014-09-07        18.2
# 2014-09-07        19.0
# 2014-09-07        21.6
# 2014-09-07        22.4
# 2014-09-07        20.6
# 2014-09-07        19.4
# 2014-09-07        20.8
# 2014-09-07        23.0
# 2014-09-07        26.8
# 2014-09-07        24.6
# 2014-09-07        22.6
# 2014-09-07        22.6
# 2014-09-07        20.6
# 2014-09-07        16.8
# 2014-09-07        21.8
# 2014-09-07        23.2
# ...                ...
# 2019-01-13        24.6
# 2019-01-13        23.4
# 2019-01-13        26.2
# 2019-01-13        28.8
# 2019-01-13        24.6
# 2019-01-13        23.4
# 2019-01-20        25.8
# 2019-01-20        24.8
# 2019-01-20        22.8
# 2019-01-20        26.2
# 2019-01-20        28.6
# 2019-01-20        28.0
# 2019-01-20        29.6
# 2019-01-20        30.8
# 2019-01-20        28.6
# 2019-01-20        28.0
# 2019-01-20        29.6
# 2019-01-20        30.8
# 2019-01-20        28.6
# 2019-01-20        28.0
# 2019-01-20        29.6
# 2019-01-20        30.8
# 2019-01-27        28.6
# 2019-01-27        24.8
# 2019-01-27        25.4
# 2019-01-27        20.6
# 2019-02-03        13.8
# 2019-02-03        11.2
# 2019-02-03        10.4
# 2019-02-03         7.8
#
# [57960 rows x 26 columns]

# %%
data['2019-02-03']
# Out:
#             drive  goal_to_go  air_yards  yards_after_catch  punt_blocked  \
# game_date
# 2019-02-03     24         0.0      393.0               75.0           0.0
# 2019-02-03     25         1.0      268.0              126.0           0.0
#
#             first_down_rush  first_down_pass  first_down_penalty  \
# game_date
# 2019-02-03              2.0             11.0                 1.0
# 2019-02-03              6.0             12.0                 4.0
#
#             interception  punt_inside_twenty  ...  return_yards  \
# game_date                                     ...
# 2019-02-03           1.0                 5.0  ...          29.0
# 2019-02-03           1.0                 3.0  ...          50.0
#
#             third_down_perc  fourth_down_perc  pass_perc  yards_per_deep_pass  \
# game_date
# 2019-02-03         0.000216               0.0   0.000320             8.181818
# 2019-02-03         0.000216               0.0   0.000354             9.000000
#
#             yards_per_rush  yards_per_short_pass  yards_per_play  home  \
# game_date
# 2019-02-03        3.444444              5.346154        4.333333     1
# 2019-02-03        4.812500              7.172414        5.985294     0
#
#             team_score
# game_date
# 2019-02-03           3
# 2019-02-03          13
#
# [2 rows x 26 columns]

# %%
df[(df.team == 'DAL') | (df.team == 'ATL')]
# Out:
#             drive  goal_to_go  air_yards  yards_after_catch  punt_blocked  \
# game_date
# 2019-01-05     24         3.0      245.0              103.0           0.0
# 2019-01-12     16         4.0      234.0              115.0           0.0
# 2015-01-04     22         9.0      230.0              188.0           0.0
# 2015-01-11     16         2.0      143.0              110.0           0.0
# 2018-01-06     24         8.0      136.0              154.0           0.0
# 2018-01-13     17        10.0      295.0               93.0           0.0
# 2017-01-14     20         8.0      316.0              172.0           0.0
# 2017-01-15     18         1.0      412.0              110.0           0.0
# 2017-01-22     18         7.0      335.0              202.0           0.0
# 2017-02-05     22         1.0      287.0               78.0           0.0
# 2018-09-06     23        15.0      380.0               92.0           0.0
# 2018-09-09     21         0.0      216.0               68.0           0.0
# 2018-09-16     20         2.0      293.0              133.0           0.0
# 2018-09-16     20         0.0      230.0               56.0           0.0
# 2018-09-23     23         4.0      308.0              152.0           1.0
# 2018-09-23     24         3.0      186.0               87.0           0.0
# 2015-11-22        4.166667             5.171429       5.281690    1
# 2015-11-22        4.368421             7.318182       5.676471    0
# 2015-11-26        2.214286             6.218750       3.719298    1
# 2015-11-29        4.833333             7.560000       5.771930    1
# 2015-12-06        3.555556             5.717949       4.833333    0
# 2015-12-07        4.041667             4.714286       5.870370    0
# 2015-12-13        3.375000             6.351351       3.709677    0
# 2015-12-13        8.550000             4.750000       5.294118    0
# 2015-12-19        6.333333             6.724138       5.517857    1
# 2015-12-20        2.515152             6.806452       4.753623    0
# 2015-12-27        2.566667             6.925926       6.016129    1
# 2015-12-27        4.840000             6.913043       5.482143    0
# 2016-01-03        6.250000             7.184211       7.529412    1
# 2016-01-03        3.538462             8.785714       6.650794    1
#
# [170 rows x 31 columns]

# %%
features = ['drive',
 'goal_to_go',
 'air_yards',
 'first_down_rush',
 'first_down_pass',
 'first_down_penalty',
 'interception',
 'tackled_for_loss',
 'pass_attempt',
 'punt_attempt',
 'fumble',
 'return_yards',
 'third_down_perc',
 'fourth_down_perc',
 'yards_per_rush',
 'yards_per_short_pass',
 'yards_per_play',
 'home']

# %%
a = data.loc[data.index.sort_values(),:].rolling(5).mean().tail(2)

# %%
a
# Out:
#             drive  goal_to_go  air_yards  yards_after_catch  punt_blocked  \
# game_date
# 2019-02-03   22.8         1.8      373.2              103.2           0.0
# 2019-02-03   23.8         0.4      321.2               91.6           0.0
#
#             first_down_rush  first_down_pass  first_down_penalty  \
# game_date
# 2019-02-03              3.6             11.4                 1.8
# 2019-02-03              3.6             10.4                 2.4
#
#             interception  punt_inside_twenty  ...  return_yards  \
# game_date                                     ...
# 2019-02-03           1.6                 2.8  ...          28.0
# 2019-02-03           1.4                 3.4  ...          37.4
#
#             third_down_perc  fourth_down_perc  pass_perc  yards_per_deep_pass  \
# game_date
# 2019-02-03         0.000216          0.000308   0.000317             8.512727
# 2019-02-03         0.000188          0.000308   0.000317             8.472727
#
#             yards_per_rush  yards_per_short_pass  yards_per_play  home  \
# game_date
# 2019-02-03        3.984722              5.864733        4.848776   0.6
# 2019-02-03        4.347222              5.834700        4.785229   0.6
#
#             team_score
# game_date
# 2019-02-03        10.4
# 2019-02-03         7.8
#
# [2 rows x 26 columns]

# %%
b = pd.DataFrame(data=a.mean())

# %%
b.transpose()
# Out:
#    drive  goal_to_go  air_yards  yards_after_catch  punt_blocked  \
# 0   23.3         1.1      347.2               97.4           0.0
#
#    first_down_rush  first_down_pass  first_down_penalty  interception  \
# 0              3.6             10.9                 2.1           1.5
#
#    punt_inside_twenty  ...  return_yards  third_down_perc  fourth_down_perc  \
# 0                 3.1  ...          32.7         0.000202          0.000308
#
#    pass_perc  yards_per_deep_pass  yards_per_rush  yards_per_short_pass  \
# 0   0.000317             8.492727        4.165972              5.849716
#
#    yards_per_play  home  team_score
# 0        4.817002   0.6         9.1
#
# [1 rows x 26 columns]

# %%
a.index
# Out:
# DatetimeIndex(['2019-02-03', '2019-02-03'], dtype='datetime64[ns]', name='game_date', freq=None)
